# %%
import psycopg2

conn = psycopg2.connect(
    dbname='seubanco',
    user='seuusuario',
    password='suasenha',
    host='localhost',
    port='5432'
)

cursor = conn.cursor()

# %%
with open('csv/area_indigena.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert("COPY area_indigena TO STDOUT WITH CSV HEADER", f)

with open('csv/cidade.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert("COPY cidade TO STDOUT WITH CSV HEADER", f)

with open('csv/relatorio_focos_queimadas.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert("COPY relatorio_focos_queimadas TO STDOUT WITH CSV HEADER", f)

with open('csv/estado.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert("COPY estado TO STDOUT WITH CSV HEADER", f)

with open('csv/unidade_conservacao.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert("COPY unidade_conservacao TO STDOUT WITH CSV HEADER", f)

with open('csv/relatorio_emissao_gases_anual.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert("COPY relatorio_emissao_gases_anual TO STDOUT WITH CSV HEADER", f)

with open('csv/relatorio_desmatamento.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert("COPY relatorio_desmatamento TO STDOUT WITH CSV HEADER", f)

with open('csv/regiao_administrativa.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert("COPY regiao_administrativa TO STDOUT WITH CSV HEADER", f)

with open('csv/estacao_meteorologica.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert("COPY estacao_meteorologica TO STDOUT WITH CSV HEADER", f)

with open('csv/cidade_unidade_conservacao.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert("COPY cidade_unidade_conservacao TO STDOUT WITH CSV HEADER", f)

with open('csv/estado_regiao_administrativa.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert("COPY estado_regiao_administrativa TO STDOUT WITH CSV HEADER", f)

with open('csv/relatorio_meteorologia1.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert(
        """COPY (
        SELECT * FROM relatorio_meteorologia
        WHERE data_horario_coleta >= '2000-01-01' AND data_horario_coleta < '2005-01-01'
        ) TO STDOUT WITH CSV HEADER
        """,
        f)

with open('csv/relatorio_meteorologia2.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert(
        """COPY (
        SELECT * FROM relatorio_meteorologia
        WHERE data_horario_coleta >= '2005-01-01' AND data_horario_coleta < '2010-01-01'
        ) TO STDOUT WITH CSV HEADER
        """,
        f)
    

with open('csv/relatorio_meteorologia3.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert(
        """COPY (
        SELECT * FROM relatorio_meteorologia
        WHERE data_horario_coleta >= '2010-01-01' AND data_horario_coleta < '2015-01-01'
        ) TO STDOUT WITH CSV HEADER
        """,
        f)

with open('csv/relatorio_meteorologia4.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert(
        """COPY (
            SELECT * FROM relatorio_meteorologia
            WHERE data_horario_coleta >= '2015-01-01' AND data_horario_coleta < '2020-01-01'
            ) TO STDOUT WITH CSV HEADER
        """,
        f)

with open('csv/relatorio_meteorologia5.csv', 'w', encoding='utf-8') as f:
    cursor.copy_expert(
        """COPY (
            SELECT * FROM relatorio_meteorologia
            WHERE data_horario_coleta >= '2020-01-01' AND data_horario_coleta < '2025-01-01'
            ) TO STDOUT WITH CSV HEADER
        """,
        f)

# %%
conn.rollback()

# %%
cursor.close()
conn.close()
